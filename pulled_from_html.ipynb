# %%
import pandas as pd

# %%
df = pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-01.csv')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5           1                  N           151           239
# 1            2.6           1                  N           239           246
# 2            0.0           1                  N           236           236
# 3            0.0           1                  N           193           193
# 4            0.0           2                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.shape
# Out:
# (7667792, 18)

# %%
df[df.tip_amount>0]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1               1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 7               1  2019-01-01 00:21:28   2019-01-01 00:28:37                1
# 8               1  2019-01-01 00:32:01   2019-01-01 00:45:39                1
# 9               1  2019-01-01 00:57:32   2019-01-01 01:09:32                2
# ...           ...                  ...                   ...              ...
# 7667781         2  2019-01-31 23:36:51   2019-01-31 23:46:08                3
# 7667782         2  2019-01-31 23:55:59   2019-02-01 00:30:41                3
# 7667785         2  2019-01-31 23:47:48   2019-02-01 00:01:08                1
# 7667786         2  2019-01-31 23:31:54   2019-01-31 23:50:36                2
# 7667787         2  2019-01-31 23:57:36   2019-02-01 00:18:39                1
#
# ...

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (2811814, 18)

# %%
df[df.tip_amount>0]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 579459          1  2019-01-03 21:43:46   2019-01-03 21:45:47                1
# 579460          1  2019-01-03 21:49:22   2019-01-03 21:59:12                1
# 592224          1  2019-01-03 22:04:40   2019-01-03 22:16:15                1
# 592225          1  2019-01-03 22:24:36   2019-01-27 10:41:17                1
# 872660          1  2019-01-05 03:50:35   2019-01-05 04:00:41                1
# ...           ...                  ...                   ...              ...
# 7667781         2  2019-01-31 23:36:51   2019-01-31 23:46:08                3
# 7667782         2  2019-01-31 23:55:59   2019-02-01 00:30:41                3
# 7667785         2  2019-01-31 23:47:48   2019-02-01 00:01:08                1
# 7667786         2  2019-01-31 23:31:54   2019-01-31 23:50:36                2
# 7667787         2  2019-01-31 23:57:36   2019-02-01 00:18:39                1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2811814 entries, 68268 to 7667791
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   object
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        int64
#  4   trip_distance          float64
#  5   RatecodeID             int64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
# dtypes: float64(9), int64(6), object(3)
# memory usage: 407.6+ MB

# %%
pd.to_datetime(df[['']])
